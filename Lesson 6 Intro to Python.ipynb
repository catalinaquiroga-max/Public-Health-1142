# %% [markdown]
# # INTRODUCTION TO PYTHON

# %% [markdown]
# ## Tasks

# %% [markdown]
# Task 1

# %%
(6+4) * 210
# Out:
# 2100

# %% [markdown]
# Task 2

# %%
x = 5
y = x
x = 7
y
# Out:
# 5

# %% [markdown]
# Task 3

# %%
for i in range(6):
    print(i**2)
# Out:
# 0
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Task 4

# %%
i = 0

while i < 10:
    print(i**2)
    i = i + 1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81

# %% [markdown]
# ## Quiz Questions

# %% [markdown]
# Quiz Question 1

# %%
3 * 833 + 75
# Out:
# 2574

# %% [markdown]
# Quiz Question 2

# %%
type(1 + 2)
type(1 + 2.)
# Out:
# float

# %% [markdown]
# Quiz Question 3

# %%
for n in [1,2,3,4,5]:
    print(n**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# Quiz Question 4

# %%
i = 1

while i**2 <= 1000:
    print(i**2)
    i = i + 1

print("Final value of i:", i)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196
# 225
# 256
# 289
# 324
# 361
# 400
# 441
# 484
# 529
# 576
# 625
# 676
# 729
# 784
# 841
# 900
# 961
# Final value of i: 32
