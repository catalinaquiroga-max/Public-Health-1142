# %% [markdown]
# # Python Collections

# %% [markdown]
# ## Task 1 Tuple of Prime Numbers

# %%
# Create tuple of first seven prime numbers
primes = (2, 3, 5, 7, 11, 13, 17)

# Return last three prime numbers
primes[-3:]
# Out:
# (11, 13, 17)

# %% [markdown]
# ## Task 2: Dictionary Creation

# %%
# Create dictionary
my_dict = {1: 'A', 2: 'B', 3: 'C', 4: 'D'}

# Return list of values
list(my_dict.values())
# Out:
# ['A', 'B', 'C', 'D']

# %% [markdown]
# ## Task 3 Set Difference Comparison

# %%
set_A = {'a', 'b', 'c', 'd', 'e', 'f'}
set_B = {'a', 'c', 'f', 'g'}

# A difference B
difference_A_B = set_A.difference(set_B)

# B difference A
difference_B_A = set_B.difference(set_A)

difference_A_B, difference_B_A
# Out:
# ({'b', 'd', 'e'}, {'g'})

# %% [markdown]
# -Set Differences are not the same
#
#
# -Set Differences not symmetric

# %% [markdown]
# ## Quiz Questions and Answers

# %% [markdown]
# ## Quiz Questions and Answers
#
# ---
#
# ### 1. How do you define a list in Python?
#
# A list is defined using square brackets.
#
# ```python
# my_list = [1, 2, 3]
# ```
#
# ---
#
# ### 2. How do you access the third element of `my_list`?
#
# ```python
# my_list[2]
# ```
#
# ---
#
# ### 3. How can you add the element "new_item" to the end of `my_list`?
#
# ```python
# my_list.append("new_item")
# ```
#
# ---
#
# ### 4. How do you create a Python tuple with the items "apple", "banana", and "cherry"?
#
# ```python
# my_tuple = ("apple", "banana", "cherry")
# ```
#
# ---
#
# ### 5. How do you access the first element of `my_tuple`?
#
# ```python
# my_tuple[0]
# ```
#
# ---
#
# ### 6. How do you define a dictionary in Python with keys "name" and "age" and values "John Doe", 30?
#
# ```python
# my_dict = {"name": "John Doe", "age": 30}
# ```
#
# ---
#
# ### 7. How can you retrieve the value for the key "name" from `my_dict`?
#
# ```python
# my_dict["name"]
# ```
#
# ---
#
# ### 8. How can you change the value associated with the key "age" in `my_dict` to 35?
#
# ```python
# my_dict["age"] = 35
# ```
#
# ---
#
# ### 9. How can you add a new key-value pair "city":"New York" to `my_dict`?
#
# ```python
# my_dict["city"] = "New York"
# ```
#
# ---
#
# ### 10. How do you create a set in Python with the items "apple", "banana", and "cherry"?
#
# ```python
# my_set = {"apple", "banana", "cherry"}
# ```
#
# ---
#
# ### 11. How do you add the item "orange" to an existing set `my_set`?
#
# ```python
# my_set.add("orange")
# ```
#
# ---
#
# ### 12. How do you remove the item "banana" from the set `my_set`?
#
# ```python
# my_set.remove("banana")
# ```
#
# ---
#
# ### 13. What is the length of a list `my_list` with elements [1, 2, 3, 4, 5]?
#
# ```python
# len([1, 2, 3, 4, 5])
# ```
#
# Result: **5**
#
# ---
#
# ### 14. What will be the result of `my_list * 2` if `my_list` is [1, 2, 3]?
#
# ```python
# [1, 2, 3] * 2
# ```
#
# Result:
#
# ```
# [1, 2, 3, 1, 2, 3]
# ```
#
# ---
#
# ### 15. What is the result of `set([1,2,2,3,4,4,4,5,5])`?
#
# ```python
# set([1,2,2,3,4,4,4,5,5])
# ```
#
# Result:
#
# ```
# {1, 2, 3, 4, 5}
# ```
